# %%
#Import the dependencies.

# Import the requests library.
import requests

# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

##  import our api keys
from config import weather_api_key  
from config import g_key

# %%
#Create a new set of 2,000 random latitudes and longitudes.


lats = np.random.uniform(low=-90.0, high=90.0, size=2000)  
lngs = np.random.uniform(low=-180.0, high=180.0, size=2000)
lat_lngs = zip(lats, lngs) 
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
#use citipy library to find the nearest city for all latitudes and longitudes
#Get the nearest city using the citipy module.

cities = []

for coordinate in coordinates:  # loop thru coordinates llist of 1500 lats and lngs
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
  
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
    
        # Print the city count to confirm sufficient count.
print(cities[:10], 'Generate', len(cities))
# Out:
# ['oistins', 'laguna', 'ginir', 'jumla', 'sept-iles', 'hobart', 'bakaly', 'illoqqortoormiut', 'thaba-tseka', 'barrow'] Generate 784

# %%
# an API Call with the OpenWeatherMap.
 

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
   #     time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
   
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | oistins
# Processing Record 2 of Set 1 | laguna
# Processing Record 3 of Set 1 | ginir
# Processing Record 4 of Set 1 | jumla
# Processing Record 5 of Set 1 | sept-iles
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | bakaly
# Processing Record 8 of Set 1 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 1 | thaba-tseka
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | leningradskiy
# Processing Record 12 of Set 1 | pafos
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | saint-francois
# Processing Record 15 of Set 1 | kosa
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | sawakin
# Processing Record 18 of Set 1 | saquena
# Processing Record 19 of Set 1 | pevek
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | safaqis
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 1 | ancud
# Processing Record 23 of Set 1 | geraldton
# Processing Record 24 of Set 1 | cherskiy
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | helong
# Processing Record 31 of Set 1 | zemen
# Processing Record 32 of Set 1 | lompoc
# Processing Record 33 of Set 1 | bara
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | raga
# Processing Record 37 of Set 1 | malakisi
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | viedma
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | norman wells
# Processing Record 44 of Set 1 | manzil salim
# Processing Record 45 of Set 1 | ushtobe
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | acapulco
# Processing Record 50 of Set 1 | mana
# Processing Record 1 of Set 2 | fort nelson
# Processing Record 2 of Set 2 | qinhuangdao
# Processing Record 3 of Set 2 | arica
# Processing Record 4 of Set 2 | ardakan
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | maua
# Processing Record 8 of Set 2 | mahebourg
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | tahlequah
# Processing Record 11 of Set 2 | bonavista
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | xuzhou
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | faanui
# Processing Record 16 of Set 2 | paamiut
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | yanam
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | merauke
# Processing Record 23 of Set 2 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 2 | urucara
# Processing Record 25 of Set 2 | shache
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | bom jardim
# Processing Record 28 of Set 2 | puri
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | butaritari
# Processing Record 31 of Set 2 | cairns
# Processing Record 32 of Set 2 | veraval
# Processing Record 33 of Set 2 | zhicheng
# Processing Record 34 of Set 2 | tateyama
# Processing Record 35 of Set 2 | astana
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | gornyy
# Processing Record 38 of Set 2 | miramar
# Processing Record 39 of Set 2 | srednekolymsk
# Processing Record 40 of Set 2 | abu kamal
# Processing Record 41 of Set 2 | albany
# Processing Record 42 of Set 2 | fairbanks
# Processing Record 43 of Set 2 | powassan
# Processing Record 44 of Set 2 | kavaratti
# Processing Record 45 of Set 2 | potiskum
# Processing Record 46 of Set 2 | mehamn
# Processing Record 47 of Set 2 | parabel
# Processing Record 48 of Set 2 | kenai
# Processing Record 49 of Set 2 | barcelona
# Processing Record 50 of Set 2 | ponta do sol
# Processing Record 1 of Set 3 | coihaique
# Processing Record 2 of Set 3 | rawson
# Processing Record 3 of Set 3 | iqaluit
# Processing Record 4 of Set 3 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 3 | tezu
# Processing Record 6 of Set 3 | mataura
# Processing Record 7 of Set 3 | parbhani
# Processing Record 8 of Set 3 | nakhon phanom
# Processing Record 9 of Set 3 | ijaki
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 3 | marcona
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 3 | angoram
# Processing Record 12 of Set 3 | ketchikan
# Processing Record 13 of Set 3 | umm lajj
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | salisbury
# Processing Record 16 of Set 3 | nanortalik
# Processing Record 17 of Set 3 | mitsamiouli
# Processing Record 18 of Set 3 | sorland
# Processing Record 19 of Set 3 | dingle
# Processing Record 20 of Set 3 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 3 | marathon
# Processing Record 22 of Set 3 | biak
# Processing Record 23 of Set 3 | twin falls
# Processing Record 24 of Set 3 | smithers
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | nara
# Processing Record 27 of Set 3 | akyab
# Processing Record 28 of Set 3 | sonoita
# Processing Record 29 of Set 3 | mae ramat
# Processing Record 30 of Set 3 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 3 | east london
# Processing Record 32 of Set 3 | vitoria
# Processing Record 33 of Set 3 | vagur
# Processing Record 34 of Set 3 | najran
# Processing Record 35 of Set 3 | thinadhoo
# Processing Record 36 of Set 3 | salinopolis
# Processing Record 37 of Set 3 | hualmay
# Processing Record 38 of Set 3 | antalaha
# Processing Record 39 of Set 3 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 3 | hasaki
# Processing Record 41 of Set 3 | pendleton
# Processing Record 42 of Set 3 | tucumcari
# Processing Record 43 of Set 3 | sompeta
# Processing Record 44 of Set 3 | nyurba
# Processing Record 45 of Set 3 | busselton
# Processing Record 46 of Set 3 | pisco
# Processing Record 47 of Set 3 | wanning
# Processing Record 48 of Set 3 | tiruvottiyur
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 3 | carnarvon
# Processing Record 50 of Set 3 | iskateley
# Processing Record 1 of Set 4 | georgetown
# Processing Record 2 of Set 4 | ahipara
# Processing Record 3 of Set 4 | kidal
# Processing Record 4 of Set 4 | bargal
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 4 | chokurdakh
# Processing Record 6 of Set 4 | cabo san lucas
# Processing Record 7 of Set 4 | along
# Processing Record 8 of Set 4 | tabas
# Processing Record 9 of Set 4 | hammerfest
# Processing Record 10 of Set 4 | brigantine
# Processing Record 11 of Set 4 | kawambwa
# Processing Record 12 of Set 4 | nuuk
# Processing Record 13 of Set 4 | ponta delgada
# Processing Record 14 of Set 4 | bonthe
# Processing Record 15 of Set 4 | sabla
# Processing Record 16 of Set 4 | port blair
# Processing Record 17 of Set 4 | young
# Processing Record 18 of Set 4 | phan rang
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 4 | korla
# Processing Record 20 of Set 4 | severo-kurilsk
# Processing Record 21 of Set 4 | saint anthony
# Processing Record 22 of Set 4 | solnechnyy
# Processing Record 23 of Set 4 | ituni
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 4 | kloulklubed
# Processing Record 25 of Set 4 | mut
# Processing Record 26 of Set 4 | ocos
# Processing Record 27 of Set 4 | jamestown
# Processing Record 28 of Set 4 | bambous virieux
# Processing Record 29 of Set 4 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 4 | eschwege
# Processing Record 31 of Set 4 | souillac
# Processing Record 32 of Set 4 | richards bay
# Processing Record 33 of Set 4 | yerbogachen
# Processing Record 34 of Set 4 | port hardy
# Processing Record 35 of Set 4 | ust-bolsheretsk
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 4 | victor harbor
# Processing Record 37 of Set 4 | klaksvik
# Processing Record 38 of Set 4 | aquiraz
# Processing Record 39 of Set 4 | cape town
# Processing Record 40 of Set 4 | diplo
# Processing Record 41 of Set 4 | san ramon de la nueva oran
# Processing Record 42 of Set 4 | yumen
# Processing Record 43 of Set 4 | wajima
# Processing Record 44 of Set 4 | waw
# Processing Record 45 of Set 4 | jurado
# Processing Record 46 of Set 4 | lagoa
# Processing Record 47 of Set 4 | westport
# Processing Record 48 of Set 4 | olafsvik
# Processing Record 49 of Set 4 | gambela
# Processing Record 50 of Set 4 | saint-pierre
# Processing Record 1 of Set 5 | tigil
# Processing Record 2 of Set 5 | ribeira brava
# Processing Record 3 of Set 5 | fereydunshahr
# Processing Record 4 of Set 5 | umzimvubu
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 5 | ganzhou
# Processing Record 6 of Set 5 | tasbuget
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 5 | yuli
# Processing Record 8 of Set 5 | tucuman
# Processing Record 9 of Set 5 | coquimbo
# Processing Record 10 of Set 5 | sulat
# Processing Record 11 of Set 5 | lazaro cardenas
# Processing Record 12 of Set 5 | shieli
# Processing Record 13 of Set 5 | denpasar
# Processing Record 14 of Set 5 | saint george
# Processing Record 15 of Set 5 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 5 | murray bridge
# Processing Record 17 of Set 5 | artigas
# Processing Record 18 of Set 5 | eskasem
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 5 | karaul
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 5 | goderich
# Processing Record 21 of Set 5 | kalianget
# Processing Record 22 of Set 5 | bacuit
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 5 | agadez
# Processing Record 24 of Set 5 | qaanaaq
# Processing Record 25 of Set 5 | houma
# Processing Record 26 of Set 5 | margate
# Processing Record 27 of Set 5 | melito di porto salvo
# Processing Record 28 of Set 5 | port elizabeth
# Processing Record 29 of Set 5 | port alfred
# Processing Record 30 of Set 5 | yellowknife
# Processing Record 31 of Set 5 | lavrentiya
# Processing Record 32 of Set 5 | el dorado
# Processing Record 33 of Set 5 | kodiak
# Processing Record 34 of Set 5 | tuktoyaktuk
# Processing Record 35 of Set 5 | kalmunai
# Processing Record 36 of Set 5 | kruisfontein
# Processing Record 37 of Set 5 | murray
# Processing Record 38 of Set 5 | swan hill
# Processing Record 39 of Set 5 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 5 | fortuna
# Processing Record 41 of Set 5 | port hueneme
# Processing Record 42 of Set 5 | palmer
# Processing Record 43 of Set 5 | pitimbu
# Processing Record 44 of Set 5 | sitka
# Processing Record 45 of Set 5 | la asuncion
# Processing Record 46 of Set 5 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 5 | fallon
# Processing Record 48 of Set 5 | oga
# Processing Record 49 of Set 5 | ribeira grande
# Processing Record 50 of Set 5 | sao joao da barra
# Processing Record 1 of Set 6 | katsuura
# Processing Record 2 of Set 6 | san policarpo
# Processing Record 3 of Set 6 | kalemie
# Processing Record 4 of Set 6 | pyaozerskiy
# Processing Record 5 of Set 6 | olinda
# Processing Record 6 of Set 6 | malwan
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 6 | hambantota
# Processing Record 8 of Set 6 | suez
# Processing Record 9 of Set 6 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 6 | asau
# Processing Record 11 of Set 6 | grand-santi
# Processing Record 12 of Set 6 | moindou
# Processing Record 13 of Set 6 | tucurui
# Processing Record 14 of Set 6 | biloela
# Processing Record 15 of Set 6 | praia
# Processing Record 16 of Set 6 | hithadhoo
# Processing Record 17 of Set 6 | saint-philippe
# Processing Record 18 of Set 6 | dakar
# Processing Record 19 of Set 6 | kununurra
# Processing Record 20 of Set 6 | narsaq
# Processing Record 21 of Set 6 | san-pedro
# Processing Record 22 of Set 6 | kvarkeno
# Processing Record 23 of Set 6 | shiraz
# Processing Record 24 of Set 6 | byron bay
# Processing Record 25 of Set 6 | suao
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 6 | teguldet
# Processing Record 27 of Set 6 | vestmannaeyjar
# Processing Record 28 of Set 6 | yaan
# Processing Record 29 of Set 6 | cap malheureux
# Processing Record 30 of Set 6 | beloha
# Processing Record 31 of Set 6 | touros
# Processing Record 32 of Set 6 | san jose
# Processing Record 33 of Set 6 | dunedin
# Processing Record 34 of Set 6 | chitral
# Processing Record 35 of Set 6 | beberibe
# Processing Record 36 of Set 6 | husavik
# Processing Record 37 of Set 6 | crvenka
# Processing Record 38 of Set 6 | esperance
# Processing Record 39 of Set 6 | lebu
# Processing Record 40 of Set 6 | langsa
# Processing Record 41 of Set 6 | plouzane
# Processing Record 42 of Set 6 | aklavik
# Processing Record 43 of Set 6 | huarmey
# Processing Record 44 of Set 6 | cidreira
# Processing Record 45 of Set 6 | tuatapere
# Processing Record 46 of Set 6 | turbat
# Processing Record 47 of Set 6 | kailua
# Processing Record 48 of Set 6 | polewali
# Processing Record 49 of Set 6 | comodoro rivadavia
# Processing Record 50 of Set 6 | marijampole
# Processing Record 1 of Set 7 | sabang
# Processing Record 2 of Set 7 | bengkulu
# Processing Record 3 of Set 7 | longyan
# Processing Record 4 of Set 7 | sakakah
# Processing Record 5 of Set 7 | kahului
# Processing Record 6 of Set 7 | te anau
# Processing Record 7 of Set 7 | san miguel
# Processing Record 8 of Set 7 | kavieng
# Processing Record 9 of Set 7 | springhill
# Processing Record 10 of Set 7 | sao domingos do maranhao
# Processing Record 11 of Set 7 | rio gallegos
# Processing Record 12 of Set 7 | hede
# Processing Record 13 of Set 7 | churapcha
# Processing Record 14 of Set 7 | kandiaro
# Processing Record 15 of Set 7 | sorvag
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 7 | boende
# Processing Record 17 of Set 7 | nguiu
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 7 | kieta
# Processing Record 19 of Set 7 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 7 | tarbagatay
# Processing Record 21 of Set 7 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 7 | palmerston
# Processing Record 23 of Set 7 | prince george
# Processing Record 24 of Set 7 | sao filipe
# Processing Record 25 of Set 7 | veere
# Processing Record 26 of Set 7 | bumba
# Processing Record 27 of Set 7 | pilikwe
# Processing Record 28 of Set 7 | kaitangata
# Processing Record 29 of Set 7 | isangel
# Processing Record 30 of Set 7 | luderitz
# Processing Record 31 of Set 7 | yenagoa
# Processing Record 32 of Set 7 | chipinge
# Processing Record 33 of Set 7 | dobrinka
# Processing Record 34 of Set 7 | guerrero negro
# Processing Record 35 of Set 7 | tiksi
# Processing Record 36 of Set 7 | ajaccio
# Processing Record 37 of Set 7 | goma
# Processing Record 38 of Set 7 | andenes
# Processing Record 39 of Set 7 | talnakh
# Processing Record 40 of Set 7 | sambava
# Processing Record 41 of Set 7 | melchor de mencos
# Processing Record 42 of Set 7 | zhigansk
# Processing Record 43 of Set 7 | wattegama
# Processing Record 44 of Set 7 | kampong thum
# Processing Record 45 of Set 7 | porto torres
# Processing Record 46 of Set 7 | sapa
# Processing Record 47 of Set 7 | quelimane
# Processing Record 48 of Set 7 | nome
# Processing Record 49 of Set 7 | vardo
# Processing Record 50 of Set 7 | hami
# Processing Record 1 of Set 8 | ust-maya
# Processing Record 2 of Set 8 | hay river
# Processing Record 3 of Set 8 | batagay-alyta
# Processing Record 4 of Set 8 | bayangol
# Processing Record 5 of Set 8 | coari
# Processing Record 6 of Set 8 | valparaiso
# Processing Record 7 of Set 8 | rengo
# Processing Record 8 of Set 8 | broken hill
# Processing Record 9 of Set 8 | grootfontein
# Processing Record 10 of Set 8 | fevralsk
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 8 | isla mujeres
# Processing Record 12 of Set 8 | grindavik
# Processing Record 13 of Set 8 | vagay
# Processing Record 14 of Set 8 | rahimatpur
# Processing Record 15 of Set 8 | yekaterinoslavka
# Processing Record 16 of Set 8 | thompson
# Processing Record 17 of Set 8 | sinkat
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 8 | bayonet point
# Processing Record 19 of Set 8 | naze
# Processing Record 20 of Set 8 | pacific grove
# Processing Record 21 of Set 8 | tisul
# Processing Record 22 of Set 8 | derac
# Processing Record 23 of Set 8 | bilibino
# Processing Record 24 of Set 8 | mongagua
# Processing Record 25 of Set 8 | halifax
# Processing Record 26 of Set 8 | san patricio
# Processing Record 27 of Set 8 | vidalia
# Processing Record 28 of Set 8 | praia da vitoria
# Processing Record 29 of Set 8 | behshahr
# Processing Record 30 of Set 8 | puksoozero
# Processing Record 31 of Set 8 | tual
# Processing Record 32 of Set 8 | perth
# Processing Record 33 of Set 8 | kakrala
# Processing Record 34 of Set 8 | lesozavodsk
# Processing Record 35 of Set 8 | belle fourche
# Processing Record 36 of Set 8 | san andres
# Processing Record 37 of Set 8 | levokumskoye
# Processing Record 38 of Set 8 | winslow
# Processing Record 39 of Set 8 | ampanihy
# Processing Record 40 of Set 8 | the valley
# Processing Record 41 of Set 8 | pemberton
# Processing Record 42 of Set 8 | kiama
# Processing Record 43 of Set 8 | sulangan
# Processing Record 44 of Set 8 | ekhabi
# Processing Record 45 of Set 8 | ambodifototra
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 8 | bathsheba
# Processing Record 47 of Set 8 | okhotsk
# Processing Record 48 of Set 8 | pasighat
# Processing Record 49 of Set 8 | manacapuru
# Processing Record 50 of Set 8 | virginia beach
# Processing Record 1 of Set 9 | namatanai
# Processing Record 2 of Set 9 | yulara
# Processing Record 3 of Set 9 | kualakapuas
# Processing Record 4 of Set 9 | brae
# Processing Record 5 of Set 9 | ust-tsilma
# Processing Record 6 of Set 9 | artyk
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 9 | longyearbyen
# Processing Record 8 of Set 9 | dhankuta
# Processing Record 9 of Set 9 | leh
# Processing Record 10 of Set 9 | lohja
# Processing Record 11 of Set 9 | muroto
# Processing Record 12 of Set 9 | vao
# Processing Record 13 of Set 9 | carutapera
# Processing Record 14 of Set 9 | tongliao
# Processing Record 15 of Set 9 | sisophon
# Processing Record 16 of Set 9 | belaya gora
# Processing Record 17 of Set 9 | sur
# Processing Record 18 of Set 9 | lata
# Processing Record 19 of Set 9 | taoudenni
# Processing Record 20 of Set 9 | sovetskiy
# Processing Record 21 of Set 9 | adela
# Processing Record 22 of Set 9 | montecristo
# Processing Record 23 of Set 9 | lasa
# Processing Record 24 of Set 9 | alencon
# Processing Record 25 of Set 9 | azanka
# Processing Record 26 of Set 9 | saint-augustin
# Processing Record 27 of Set 9 | aasiaat
# Processing Record 28 of Set 9 | vila velha
# Processing Record 29 of Set 9 | komsomolskiy
# Processing Record 30 of Set 9 | elizabeth city
# Processing Record 31 of Set 9 | aitape
# Processing Record 32 of Set 9 | yamada
# Processing Record 33 of Set 9 | toamasina
# Processing Record 34 of Set 9 | meulaboh
# Processing Record 35 of Set 9 | buraydah
# Processing Record 36 of Set 9 | shingu
# Processing Record 37 of Set 9 | sungaipenuh
# Processing Record 38 of Set 9 | lorengau
# Processing Record 39 of Set 9 | mayo
# Processing Record 40 of Set 9 | avera
# Processing Record 41 of Set 9 | ondorhaan
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 9 | berlevag
# Processing Record 43 of Set 9 | kremenki
# Processing Record 44 of Set 9 | alice springs
# Processing Record 45 of Set 9 | yar-sale
# Processing Record 46 of Set 9 | severo-yeniseyskiy
# Processing Record 47 of Set 9 | warwick
# Processing Record 48 of Set 9 | alta floresta
# Processing Record 49 of Set 9 | bull savanna
# Processing Record 50 of Set 9 | marawi
# Processing Record 1 of Set 10 | santa maria
# Processing Record 2 of Set 10 | markova
# Processing Record 3 of Set 10 | ruteng
# Processing Record 4 of Set 10 | nagapattinam
# Processing Record 5 of Set 10 | muswellbrook
# Processing Record 6 of Set 10 | baykit
# Processing Record 7 of Set 10 | waingapu
# Processing Record 8 of Set 10 | vestmanna
# Processing Record 9 of Set 10 | alofi
# Processing Record 10 of Set 10 | adrar
# Processing Record 11 of Set 10 | osa
# Processing Record 12 of Set 10 | paracuru
# Processing Record 13 of Set 10 | cayenne
# Processing Record 14 of Set 10 | kurilsk
# Processing Record 15 of Set 10 | paita
# Processing Record 16 of Set 10 | anavissos
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 10 | laiagam
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 10 | nioro
# Processing Record 19 of Set 10 | makakilo city
# Processing Record 20 of Set 10 | torbay
# Processing Record 21 of Set 10 | mackay
# Processing Record 22 of Set 10 | san cristobal
# Processing Record 23 of Set 10 | sechura
# Processing Record 24 of Set 10 | san fernando
# Processing Record 25 of Set 10 | poum
# Processing Record 26 of Set 10 | ferrol
# Processing Record 27 of Set 10 | noumea
# Processing Record 28 of Set 10 | ghanzi
# Processing Record 29 of Set 10 | udachnyy
# Processing Record 30 of Set 10 | juneau
# Processing Record 31 of Set 10 | bandarbeyla
# Processing Record 32 of Set 10 | rio grande
# Processing Record 33 of Set 10 | kizhinga
# Processing Record 34 of Set 10 | itarema
# Processing Record 35 of Set 10 | broome
# Processing Record 36 of Set 10 | palana
# Processing Record 37 of Set 10 | amasia
# Processing Record 38 of Set 10 | port keats
# Processing Record 39 of Set 10 | cap-aux-meules
# Processing Record 40 of Set 10 | port hedland
# Processing Record 41 of Set 10 | siilinjarvi
# Processing Record 42 of Set 10 | ostrovnoy
# Processing Record 43 of Set 10 | oranjestad
# Processing Record 44 of Set 10 | sandwick
# Processing Record 45 of Set 10 | hearst
# Processing Record 46 of Set 10 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 10 | sibu
# Processing Record 48 of Set 10 | haines junction
# Processing Record 49 of Set 10 | amuntai
# Processing Record 50 of Set 10 | abnub
# Processing Record 1 of Set 11 | jabinyanah
# Processing Record 2 of Set 11 | allapalli
# Processing Record 3 of Set 11 | marienburg
# Processing Record 4 of Set 11 | aleksandro-nevskiy
# Processing Record 5 of Set 11 | ilulissat
# Processing Record 6 of Set 11 | oudtshoorn
# Processing Record 7 of Set 11 | la primavera
# Processing Record 8 of Set 11 | bhinmal
# Processing Record 9 of Set 11 | bambanglipuro
# Processing Record 10 of Set 11 | los zacatones
# Processing Record 11 of Set 11 | lepseny
# Processing Record 12 of Set 11 | yeppoon
# Processing Record 13 of Set 11 | dryden
# Processing Record 14 of Set 11 | catemaco
# Processing Record 15 of Set 11 | tekkali
# Processing Record 16 of Set 11 | port macquarie
# Processing Record 17 of Set 11 | mugur-aksy
# Processing Record 18 of Set 11 | baruun-urt
# Processing Record 19 of Set 11 | abu dhabi
# Processing Record 20 of Set 11 | fort frances
# Processing Record 21 of Set 11 | mount gambier
# Processing Record 22 of Set 11 | ha noi
# Processing Record 23 of Set 11 | jimeta
# Processing Record 24 of Set 11 | kirakira
# Processing Record 25 of Set 11 | roma
# Processing Record 26 of Set 11 | kananga
# Processing Record 27 of Set 11 | erenhot
# Processing Record 28 of Set 11 | alihe
# Processing Record 29 of Set 11 | apartado
# Processing Record 30 of Set 11 | saldanha
# Processing Record 31 of Set 11 | aswan
# Processing Record 32 of Set 11 | pavilosta
# Processing Record 33 of Set 11 | volax
# Processing Record 34 of Set 11 | college
# Processing Record 35 of Set 11 | nishihara
# Processing Record 36 of Set 11 | yantai
# Processing Record 37 of Set 11 | zhangjiakou
# Processing Record 38 of Set 11 | nandurbar
# Processing Record 39 of Set 11 | coahuayana
# Processing Record 40 of Set 11 | samarai
# Processing Record 41 of Set 11 | mvangue
# Processing Record 42 of Set 11 | nagato
# Processing Record 43 of Set 11 | safaga
# Processing Record 44 of Set 11 | tamandare
# Processing Record 45 of Set 11 | kastamonu
# Processing Record 46 of Set 11 | dianopolis
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 11 | sindand
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 11 | sisimiut
# Processing Record 49 of Set 11 | spanish town
# Processing Record 50 of Set 11 | serebryanyy bor
# Processing Record 1 of Set 12 | sao gabriel da cachoeira
# Processing Record 2 of Set 12 | jieznas
# Processing Record 3 of Set 12 | mangaratiba
# Processing Record 4 of Set 12 | taian
# Processing Record 5 of Set 12 | marivan
# Processing Record 6 of Set 12 | port lincoln
# Processing Record 7 of Set 12 | stornoway
# Processing Record 8 of Set 12 | tsiroanomandidy
# Processing Record 9 of Set 12 | babstovo
# Processing Record 10 of Set 12 | otterup
# Processing Record 11 of Set 12 | quatre cocos
# Processing Record 12 of Set 12 | kotelnikovo
# Processing Record 13 of Set 12 | burica
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 12 | atasu
# Processing Record 15 of Set 12 | kovdor
# Processing Record 16 of Set 12 | great yarmouth
# Processing Record 17 of Set 12 | seoul
# Processing Record 18 of Set 12 | taganak
# Processing Record 19 of Set 12 | boyolangu
# Processing Record 20 of Set 12 | qasigiannguit
# Processing Record 21 of Set 12 | opuwo
# Processing Record 22 of Set 12 | chapais
# Processing Record 23 of Set 12 | lahad datu
# Processing Record 24 of Set 12 | zhengjiatun
# Processing Record 25 of Set 12 | amahai
# Processing Record 26 of Set 12 | constitucion
# Processing Record 27 of Set 12 | boralday
# Processing Record 28 of Set 12 | kopavogur
# Processing Record 29 of Set 12 | inuvik
# Processing Record 30 of Set 12 | port moresby
# Processing Record 31 of Set 12 | ancona
# Processing Record 32 of Set 12 | santa maria del oro
# Processing Record 33 of Set 12 | alice
# Processing Record 34 of Set 12 | san quintin
# Processing Record 35 of Set 12 | mwingi
# Processing Record 36 of Set 12 | bosaso
# Processing Record 37 of Set 12 | yagodnoye
# Processing Record 38 of Set 12 | coos bay
# Processing Record 39 of Set 12 | meridian
# Processing Record 40 of Set 12 | amposta
# Processing Record 41 of Set 12 | champerico
# Processing Record 42 of Set 12 | sinnamary
# Processing Record 43 of Set 12 | aykhal
# Processing Record 44 of Set 12 | balakhninskiy
# Processing Record 45 of Set 12 | caluquembe
# Processing Record 46 of Set 12 | turukhansk
# Processing Record 47 of Set 12 | portland
# Processing Record 48 of Set 12 | casablanca
# Processing Record 49 of Set 12 | gejiu
# Processing Record 50 of Set 12 | mayya
# Processing Record 1 of Set 13 | kolokani
# Processing Record 2 of Set 13 | andros town
# Processing Record 3 of Set 13 | fountain hills
# Processing Record 4 of Set 13 | ntungamo
# Processing Record 5 of Set 13 | alghero
# Processing Record 6 of Set 13 | soyo
# Processing Record 7 of Set 13 | dauriya
# Processing Record 8 of Set 13 | caravelas
# Processing Record 9 of Set 13 | freital
# Processing Record 10 of Set 13 | agadir
# Processing Record 11 of Set 13 | codrington
# Processing Record 12 of Set 13 | kirishi
# Processing Record 13 of Set 13 | grande prairie
# Processing Record 14 of Set 13 | atambua
# Processing Record 15 of Set 13 | punta alta
# Processing Record 16 of Set 13 | jiddah
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 13 | karratha
# Processing Record 18 of Set 13 | nordby
# Processing Record 19 of Set 13 | havelock
# Processing Record 20 of Set 13 | belmonte
# Processing Record 21 of Set 13 | monrovia
# Processing Record 22 of Set 13 | borujerd
# Processing Record 23 of Set 13 | corinto
# Processing Record 24 of Set 13 | benghazi
# Processing Record 25 of Set 13 | arlit
# Processing Record 26 of Set 13 | lalmohan
# Processing Record 27 of Set 13 | dhidhdhoo
# Processing Record 28 of Set 13 | nantucket
# Processing Record 29 of Set 13 | la huacana
# Processing Record 30 of Set 13 | araouane
# Processing Record 31 of Set 13 | barra da estiva
# Processing Record 32 of Set 13 | clearwater
# Processing Record 33 of Set 13 | sao felix do xingu
# Processing Record 34 of Set 13 | muli
# Processing Record 35 of Set 13 | chalus
# Processing Record 36 of Set 13 | mezen
# Processing Record 37 of Set 13 | bolungarvik
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 13 | kudahuvadhoo
# Processing Record 39 of Set 13 | hervey bay
# Processing Record 40 of Set 13 | chililabombwe
# Processing Record 41 of Set 13 | chiredzi
# Processing Record 42 of Set 13 | magdalena
# Processing Record 43 of Set 13 | beringovskiy
# Processing Record 44 of Set 13 | ures
# Processing Record 45 of Set 13 | mormugao
# Processing Record 46 of Set 13 | ust-ilimsk
# Processing Record 47 of Set 13 | falealupo
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 13 | north myrtle beach
# Processing Record 49 of Set 13 | djibo
# Processing Record 50 of Set 13 | bireun
# Processing Record 1 of Set 14 | kaharlyk
# Processing Record 2 of Set 14 | homer
# Processing Record 3 of Set 14 | nizwa
# Processing Record 4 of Set 14 | impfondo
# Processing Record 5 of Set 14 | santo tomas
# Processing Record 6 of Set 14 | shubarshi
# Processing Record 7 of Set 14 | doha
# Processing Record 8 of Set 14 | lima
# Processing Record 9 of Set 14 | uyuni
# Processing Record 10 of Set 14 | tacuarembo
# Processing Record 11 of Set 14 | kindu
# Processing Record 12 of Set 14 | martapura
# Processing Record 13 of Set 14 | taltal
# Processing Record 14 of Set 14 | port augusta
# Processing Record 15 of Set 14 | loiza
# Processing Record 16 of Set 14 | dudinka
# Processing Record 17 of Set 14 | rovaniemi
# Processing Record 18 of Set 14 | zhuhai
# Processing Record 19 of Set 14 | polunochnoye
# Processing Record 20 of Set 14 | novi pazar
# Processing Record 21 of Set 14 | hohhot
# Processing Record 22 of Set 14 | trelew
# Processing Record 23 of Set 14 | the pas
# Processing Record 24 of Set 14 | kabanjahe
# Processing Record 25 of Set 14 | chumikan
# Processing Record 26 of Set 14 | banda aceh
# Processing Record 27 of Set 14 | tam ky
# Processing Record 28 of Set 14 | kamenskoye
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 14 | waharoa
# Processing Record 30 of Set 14 | anadyr
# Processing Record 31 of Set 14 | gat
# Processing Record 32 of Set 14 | amapa
# Processing Record 33 of Set 14 | mitu
# Processing Record 34 of Set 14 | la rioja
# Processing Record 35 of Set 14 | tocopilla
# Processing Record 36 of Set 14 | williston
# Processing Record 37 of Set 14 | mantena
# Processing Record 38 of Set 14 | cuamba
# Processing Record 39 of Set 14 | cameron park
# Processing Record 40 of Set 14 | koslan
# Processing Record 41 of Set 14 | tiznit
# Processing Record 42 of Set 14 | kijang
# Processing Record 43 of Set 14 | ust-omchug
# Processing Record 44 of Set 14 | nemuro
# Processing Record 45 of Set 14 | sioux lookout
# Processing Record 46 of Set 14 | valea sarii
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 14 | parapotamos
# Processing Record 48 of Set 14 | cumaribo
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 14 | imbituba
# Processing Record 50 of Set 14 | yellandu
# Processing Record 1 of Set 15 | kargasok
# Processing Record 2 of Set 15 | savannah bight
# Processing Record 3 of Set 15 | changde
# Processing Record 4 of Set 15 | frejus
# Processing Record 5 of Set 15 | buala
# Processing Record 6 of Set 15 | nongstoin
# Processing Record 7 of Set 15 | mulanay
# Processing Record 8 of Set 15 | laukaa
# Processing Record 9 of Set 15 | hofn
# Processing Record 10 of Set 15 | toliary
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 15 | krasnoselkup
# Processing Record 12 of Set 15 | wewak
# Processing Record 13 of Set 15 | qaqortoq
# Processing Record 14 of Set 15 | tunxi
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 15 | los llanos de aridane
# Processing Record 16 of Set 15 | havoysund
# Processing Record 17 of Set 15 | kazalinsk
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 15 | vostok
# Processing Record 19 of Set 15 | zhanaozen
# Processing Record 20 of Set 15 | fare
# Processing Record 21 of Set 15 | sakaiminato
# Processing Record 22 of Set 15 | hobyo
# Processing Record 23 of Set 15 | cervo
# Processing Record 24 of Set 15 | muramvya
# Processing Record 25 of Set 15 | porbandar
# Processing Record 26 of Set 15 | havre-saint-pierre
# Processing Record 27 of Set 15 | kuching
# Processing Record 28 of Set 15 | agbor
# Processing Record 29 of Set 15 | grenfell
# Processing Record 30 of Set 15 | labutta
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 15 | lauro muller
# Processing Record 32 of Set 15 | la ronge
# Processing Record 33 of Set 15 | zakamensk
# Processing Record 34 of Set 15 | porto novo
# Processing Record 35 of Set 15 | sayville
# Processing Record 36 of Set 15 | kutum
# Processing Record 37 of Set 15 | marrakesh
# Processing Record 38 of Set 15 | qui nhon
# Processing Record 39 of Set 15 | bundaberg
# Processing Record 40 of Set 15 | tumaco
# Processing Record 41 of Set 15 | tecoanapa
# Processing Record 42 of Set 15 | flin flon
# Processing Record 43 of Set 15 | balikpapan
# Processing Record 44 of Set 15 | hurghada
# Processing Record 45 of Set 15 | tunduru
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 15 | vila franca do campo
# Processing Record 47 of Set 15 | graaff-reinet
# Processing Record 48 of Set 15 | omboue
# Processing Record 49 of Set 15 | galgani
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 15 | henties bay
# Processing Record 1 of Set 16 | mananjary
# Processing Record 2 of Set 16 | hays
# Processing Record 3 of Set 16 | jiaxing
# Processing Record 4 of Set 16 | padang
# Processing Record 5 of Set 16 | lentvaris
# Processing Record 6 of Set 16 | lai
# Processing Record 7 of Set 16 | jujuy
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 16 | inirida
# Processing Record 9 of Set 16 | novo aripuana
# Processing Record 10 of Set 16 | carikar
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 16 | channel-port aux basques
# Processing Record 12 of Set 16 | grand gaube
# Processing Record 13 of Set 16 | omsukchan
# Processing Record 14 of Set 16 | khani
# Processing Record 15 of Set 16 | kuche
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 16 | mount isa
# Processing Record 17 of Set 16 | oceanside
# Processing Record 18 of Set 16 | karabulak
# Processing Record 19 of Set 16 | recea
# Processing Record 20 of Set 16 | rehoboth
# Processing Record 21 of Set 16 | verkhnevilyuysk
# Processing Record 22 of Set 16 | hienghene
# Processing Record 23 of Set 16 | dukat
# Processing Record 24 of Set 16 | skjervoy
# Processing Record 25 of Set 16 | genhe
# Processing Record 26 of Set 16 | moranbah
# Processing Record 27 of Set 16 | prince rupert
# Processing Record 28 of Set 16 | rudbar
# Processing Record 29 of Set 16 | apache junction
# Processing Record 30 of Set 16 | tatarskaya pishlya
# Processing Record 31 of Set 16 | tura
# Processing Record 32 of Set 16 | letterkenny
# Processing Record 33 of Set 16 | mareeba
# Processing Record 34 of Set 16 | gizo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
len(city_data)
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Oistins  13.0667  -59.5333     77.09        73          40
# 1         Laguna  38.4210 -121.4238     61.09        64          40
# 2          Ginir   7.1333   40.7000     72.03        34           0
# 3          Jumla  29.2747   82.1838     71.02        23           0
# 4      Sept-Iles  50.2001  -66.3821     10.92        92          20
# 5         Hobart -42.8794  147.3294     67.86        87          75
# 6         Bakaly  55.1789   53.8028     13.89        88          82
# 7    Thaba-Tseka -29.5220   28.6084     54.30        74          42
# 8         Barrow  71.2906 -156.7887     -0.38        71         100
# 9  Leningradskiy  69.3833  178.4167    -17.09        97          35
#
#    Wind Speed Country Current Description                 Date
# 0       20.71      BB    scattered clouds  2022-03-15 07:23:26
# 1        8.05      US    scattered clouds  2022-03-15 07:18:34
# 2        8.46      ET           clear sky  2022-03-15 07:23:27
# 3        6.73      NP           clear sky  2022-03-15 07:23:27
# 4        6.91      CA          few clouds  2022-03-15 07:21:56
# 5       11.50      AU       broken clouds  2022-03-15 07:23:28
# 6        7.76      RU       broken clouds  2022-03-15 07:23:28
# 7        3.15      LS    scattered clouds  2022-03-15 07:20:21
# 8       10.36      US     overcast clouds  2022-03-15 07:23:29
# 9        3.22      RU    scattered clouds  2022-03-15 07:23:29

# %%
#create output file(csv)
output_data_file = "WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
